# %% [markdown]
# # Block B Volume Interaction
#
# Generated by `scripts/dali_tfi_deep_dive.py`.

# %% [markdown]
# ## Volume-Regime Hit-Rate By Magnitude
#
# Rolling volume is a trailing 300-second trade-count window computed from cached market-second bars.
#
# ```csv
# family_label,horizon_seconds,volume_bucket,sign_convention,magnitude_bucket,n_obs,hit_rate_pct,hit_rate_ci_low_pct,mean_return_cents,net_edge_after_1tick_cents
# ai_product,30,bottom_quartile,inverse_maker_side,bottom_decile,468,45.2991,40.3846,4.7259,3.7259
# ai_product,30,bottom_quartile,inverse_maker_side,bottom_quartile_ex_decile,691,47.3227,43.7048,4.6628,3.6628
# ai_product,30,bottom_quartile,inverse_maker_side,middle_two_quartiles,2318,45.7291,43.8945,3.5948,2.5948
# ai_product,30,bottom_quartile,inverse_maker_side,top_decile,465,44.5161,39.9892,3.0888,2.0888
# ai_product,30,bottom_quartile,inverse_maker_side,top_quartile_ex_decile,694,46.6859,42.4316,3.8069,2.8069
# ai_product,30,bottom_quartile,maker_side,bottom_decile,468,43.1624,38.9904,-4.7259,-5.7259
# ai_product,30,bottom_quartile,maker_side,bottom_quartile_ex_decile,691,44.1389,40.5137,-4.6628,-5.6628
# ai_product,30,bottom_quartile,maker_side,middle_two_quartiles,2318,46.7645,44.6711,-3.5948,-4.5948
# ai_product,30,bottom_quartile,maker_side,top_decile,465,44.5161,40.3172,-3.0888,-4.0888
# ai_product,30,bottom_quartile,maker_side,top_quartile_ex_decile,694,46.2536,43.0079,-3.8069,-4.8069
# ai_product,30,middle_two_quartiles,inverse_maker_side,bottom_decile,645,41.7054,37.8295,2.3267,1.3267
# ai_product,30,middle_two_quartiles,inverse_maker_side,bottom_quartile_ex_decile,967,46.7425,43.6892,4.4804,3.4804
# ai_product,30,middle_two_quartiles,inverse_maker_side,middle_two_quartiles,3223,46.9749,45.249,3.4694,2.4694
# ai_product,30,middle_two_quartiles,inverse_maker_side,top_decile,645,49.6124,45.9651,4.0829,3.0829
# ai_product,30,middle_two_quartiles,inverse_maker_side,top_quartile_ex_decile,967,46.7425,43.3195,3.529,2.529
# ai_product,30,middle_two_quartiles,maker_side,bottom_decile,645,52.7132,49.2209,-2.3267,-3.3267
# ai_product,30,middle_two_quartiles,maker_side,bottom_quartile_ex_decile,967,46.4323,43.3247,-4.4804,-5.4804
# ai_product,30,middle_two_quartiles,maker_side,middle_two_quartiles,3223,48.0608,46.4459,-3.4694,-4.4694
# ai_product,30,middle_two_quartiles,maker_side,top_decile,645,48.6822,45.2713,-4.0829,-5.0829
# ai_product,30,middle_two_quartiles,maker_side,top_quartile_ex_decile,967,50.1551,46.8459,-3.529,-4.529
# ai_product,30,top_decile,inverse_maker_side,bottom_decile,151,49.6689,41.7219,3.5265,2.5265
# ai_product,30,top_decile,inverse_maker_side,bottom_quartile_ex_decile,226,49.115,42.9204,2.7156,1.7156
# ai_product,30,top_decile,inverse_maker_side,middle_two_quartiles,752,49.867,46.2068,4.5012,3.5012
# ai_product,30,top_decile,inverse_maker_side,top_decile,151,47.0199,39.7351,6.7522,5.7522
# ai_product,30,top_decile,inverse_maker_side,top_quartile_ex_decile,227,50.2203,43.6123,2.9705,1.9705
# ai_product,30,top_decile,maker_side,bottom_decile,151,46.3576,39.0728,-3.5265,-4.5265
# ai_product,30,top_decile,maker_side,bottom_quartile_ex_decile,226,43.3628,37.8208,-2.7156,-3.7156
# ai_product,30,top_decile,maker_side,middle_two_quartiles,752,43.75,40.6217,-4.5012,-5.5012
# ai_product,30,top_decile,maker_side,top_decile,151,52.3179,44.3709,-6.7522,-7.7522
# ai_product,30,top_decile,maker_side,top_quartile_ex_decile,227,44.9339,37.8855,-2.9705,-3.9705
# ai_product,30,top_quartile,inverse_maker_side,bottom_decile,377,50.6631,45.6233,3.6078,2.6078
# ai_product,30,top_quartile,inverse_maker_side,bottom_quartile_ex_decile,587,48.0409,43.9523,1.4038,0.4038
# ai_product,30,top_quartile,inverse_maker_side,middle_two_quartiles,1861,48.0924,45.8611,4.4469,3.4469
# ai_product,30,top_quartile,inverse_maker_side,top_decile,377,48.5411,43.3621,6.7148,5.7148
# ai_product,30,top_quartile,inverse_maker_side,top_quartile_ex_decile,565,47.4336,43.8938,1.9617,0.9617
# ai_product,30,top_quartile,maker_side,bottom_decile,377,45.6233,39.5225,-3.6078,-4.6078
# ai_product,30,top_quartile,maker_side,bottom_quartile_ex_decile,587,45.9966,42.1593,-1.4038,-2.4038
# ai_product,30,top_quartile,maker_side,middle_two_quartiles,1861,47.1252,44.8939,-4.4469,-5.4469
# ai_product,30,top_quartile,maker_side,top_decile,377,50.6631,45.8886,-6.7148,-7.7148
# ai_product,30,top_quartile,maker_side,top_quartile_ex_decile,565,48.8496,44.4248,-1.9617,-2.9617
# ai_product,120,bottom_quartile,inverse_maker_side,bottom_decile,405,44.6914,40.2469,3.3374,2.3374
# ai_product,120,bottom_quartile,inverse_maker_side,bottom_quartile_ex_decile,660,46.0606,42.1932,3.4733,2.4733
# ai_product,120,bottom_quartile,inverse_maker_side,middle_two_quartiles,1965,44.7837,42.5445,3.7557,2.7557
# ai_product,120,bottom_quartile,inverse_maker_side,top_decile,405,43.9506,39.5062,2.714,1.714
# ai_product,120,bottom_quartile,inverse_maker_side,top_quartile_ex_decile,606,46.0396,42.4876,2.2751,1.2751
# ai_product,120,bottom_quartile,maker_side,bottom_decile,405,44.6914,40.0,-3.3374,-4.3374
# ai_product,120,bottom_quartile,maker_side,bottom_quartile_ex_decile,660,45.6061,42.1932,-3.4733,-4.4733
# ai_product,120,bottom_quartile,maker_side,middle_two_quartiles,1965,48.6514,46.3613,-3.7557,-4.7557
# ai_product,120,bottom_quartile,maker_side,top_decile,405,47.4074,42.8333,-2.714,-3.714
# ai_product,120,bottom_quartile,maker_side,top_quartile_ex_decile,606,48.5149,44.7979,-2.2751,-3.2751
# ai_product,120,middle_two_quartiles,inverse_maker_side,bottom_decile,601,47.9201,43.9268,3.1261,2.1261
# ai_product,120,middle_two_quartiles,inverse_maker_side,bottom_quartile_ex_decile,900,46.0,42.8889,2.7244,1.7244
# ai_product,120,middle_two_quartiles,inverse_maker_side,middle_two_quartiles,2998,46.6311,44.8299,3.4103,2.4103
# ai_product,120,middle_two_quartiles,inverse_maker_side,top_decile,601,49.7504,46.3353,5.9051,4.9051
# ai_product,120,middle_two_quartiles,inverse_maker_side,top_quartile_ex_decile,901,45.394,42.1754,4.1824,3.1824
# ai_product,120,middle_two_quartiles,maker_side,bottom_decile,601,48.0865,44.1722,-3.1261,-4.1261
# ai_product,120,middle_two_quartiles,maker_side,bottom_quartile_ex_decile,900,51.0,47.5556,-2.7244,-3.7244
# ai_product,120,middle_two_quartiles,maker_side,middle_two_quartiles,2998,49.3996,47.6634,-3.4103,-4.4103
# ai_product,120,middle_two_quartiles,maker_side,top_decile,601,49.0849,45.5907,-5.9051,-6.9051
# ai_product,120,middle_two_quartiles,maker_side,top_quartile_ex_decile,901,51.7203,48.2214,-4.1824,-5.1824
# ai_product,120,top_decile,inverse_maker_side,bottom_decile,135,49.6296,42.963,2.8222,1.8222
# ai_product,120,top_decile,inverse_maker_side,bottom_quartile_ex_decile,203,47.2906,41.8719,-1.5819,-2.5819
# ai_product,120,top_decile,inverse_maker_side,middle_two_quartiles,669,49.6263,46.2593,4.3226,3.3226
# ai_product,120,top_decile,inverse_maker_side,top_decile,135,56.2963,49.2407,9.2355,8.2355
# ai_product,120,top_decile,inverse_maker_side,top_quartile_ex_decile,201,49.7512,43.0224,-1.1588,-2.1588
# ai_product,120,top_decile,maker_side,bottom_decile,135,48.8889,40.0,-2.8222,-3.8222
# ai_product,120,top_decile,maker_side,bottom_quartile_ex_decile,203,52.7094,45.8128,1.5819,0.5819
# ai_product,120,top_decile,maker_side,middle_two_quartiles,669,46.0389,42.4514,-4.3226,-5.3226
# ai_product,120,top_decile,maker_side,top_decile,135,43.7037,35.5185,-9.2355,-10.2355
# ai_product,120,top_decile,maker_side,top_quartile_ex_decile,201,50.2488,43.2836,1.1588,0.1588
# ai_product,120,top_quartile,inverse_maker_side,bottom_decile,339,48.9676,43.3628,3.5339,2.5339
# ai_product,120,top_quartile,inverse_maker_side,bottom_quartile_ex_decile,507,45.3649,41.2229,0.2852,-0.7148
# ai_product,120,top_quartile,inverse_maker_side,middle_two_quartiles,1692,47.695,45.2999,3.9183,2.9183
# ai_product,120,top_quartile,inverse_maker_side,top_decile,339,47.4926,42.1829,6.8567,5.8567
# ai_product,120,top_quartile,inverse_maker_side,top_quartile_ex_decile,507,51.2821,47.14,2.1191,1.1191
# ai_product,120,top_quartile,maker_side,bottom_decile,339,49.5575,44.233,-3.5339,-4.5339
# ai_product,120,top_quartile,maker_side,bottom_quartile_ex_decile,507,53.0572,48.9152,-0.2852,-1.2852
# ai_product,120,top_quartile,maker_side,middle_two_quartiles,1692,49.6454,47.4557,-3.9183,-4.9183
# ai_product,120,top_quartile,maker_side,top_decile,339,51.9174,46.7478,-6.8567,-7.8567
# ai_product,120,top_quartile,maker_side,top_quartile_ex_decile,507,48.3235,44.1815,-2.1191,-3.1191
# ai_product,300,bottom_quartile,inverse_maker_side,bottom_decile,370,46.7568,41.6216,4.4088,3.4088
# ai_product,300,bottom_quartile,inverse_maker_side,bottom_quartile_ex_decile,551,44.1016,40.2904,2.4819,1.4819
# ai_product,300,bottom_quartile,inverse_maker_side,middle_two_quartiles,1840,45.8152,43.6128,3.6304,2.6304
# ai_product,300,bottom_quartile,inverse_maker_side,top_decile,370,47.5676,42.4324,4.52,3.52
# ai_product,300,bottom_quartile,inverse_maker_side,top_quartile_ex_decile,551,47.0054,43.0036,3.2613,2.2613
# ai_product,300,bottom_quartile,maker_side,bottom_decile,370,45.1351,40.0,-4.4088,-5.4088
# ai_product,300,bottom_quartile,maker_side,bottom_quartile_ex_decile,551,50.6352,46.5472,-2.4819,-3.4819
# ai_product,300,bottom_quartile,maker_side,middle_two_quartiles,1840,47.1739,45.0,-3.6304,-4.6304
# ai_product,300,bottom_quartile,maker_side,top_decile,370,48.3784,43.5135,-4.52,-5.52
# ai_product,300,bottom_quartile,maker_side,top_quartile_ex_decile,551,48.6388,44.5508,-3.2613,-4.2613
# ai_product,300,middle_two_quartiles,inverse_maker_side,bottom_decile,558,47.3118,42.7375,3.0227,2.0227
# ai_product,300,middle_two_quartiles,inverse_maker_side,bottom_quartile_ex_decile,835,46.9461,43.5868,2.4581,1.4581
# ai_product,300,middle_two_quartiles,inverse_maker_side,middle_two_quartiles,2785,46.6068,44.5377,3.3525,2.3525
# ai_product,300,middle_two_quartiles,inverse_maker_side,top_decile,558,49.4624,45.0672,5.4152,4.4152
# ai_product,300,middle_two_quartiles,inverse_maker_side,top_quartile_ex_decile,835,49.5808,46.4671,4.8557,3.8557
# ai_product,300,middle_two_quartiles,maker_side,bottom_decile,558,50.5376,46.4158,-3.0227,-4.0227
# ai_product,300,middle_two_quartiles,maker_side,bottom_quartile_ex_decile,835,49.7006,45.9251,-2.4581,-3.4581
# ai_product,300,middle_two_quartiles,maker_side,middle_two_quartiles,2785,50.8438,49.1014,-3.3525,-4.3525
# ai_product,300,middle_two_quartiles,maker_side,top_decile,558,49.4624,45.2464,-5.4152,-6.4152
# ai_product,300,middle_two_quartiles,maker_side,top_quartile_ex_decile,835,48.024,44.7904,-4.8557,-5.8557
# ai_product,300,top_decile,inverse_maker_side,bottom_decile,126,47.619,39.6825,6.4153,5.4153
# ai_product,300,top_decile,inverse_maker_side,bottom_quartile_ex_decile,188,47.8723,42.0213,5.7382,4.7382
# ai_product,300,top_decile,inverse_maker_side,middle_two_quartiles,628,48.5669,44.6616,4.5932,3.5932
# ai_product,300,top_decile,inverse_maker_side,top_decile,126,58.7302,51.1706,9.1933,8.1933
# ai_product,300,top_decile,inverse_maker_side,top_quartile_ex_decile,188,47.8723,41.2101,1.6437,0.6437
# ai_product,300,top_decile,maker_side,bottom_decile,126,52.381,43.6508,-6.4153,-7.4153
# ai_product,300,top_decile,maker_side,bottom_quartile_ex_decile,188,51.0638,44.1489,-5.7382,-6.7382
# ai_product,300,top_decile,maker_side,middle_two_quartiles,628,46.8153,42.91,-4.5932,-5.5932
# ai_product,300,top_decile,maker_side,top_decile,126,41.2698,33.3333,-9.1933,-10.1933
# ai_product,300,top_decile,maker_side,top_quartile_ex_decile,188,50.0,42.5532,-1.6437,-2.6437
# ai_product,300,top_quartile,inverse_maker_side,bottom_decile,309,51.1327,45.1375,5.0308,4.0308
# ai_product,300,top_quartile,inverse_maker_side,bottom_quartile_ex_decile,473,48.203,43.4408,4.2086,3.2086
# ai_product,300,top_quartile,inverse_maker_side,middle_two_quartiles,1532,48.3681,46.1146,4.1791,3.1791
# ai_product,300,top_quartile,inverse_maker_side,top_decile,309,52.7508,47.2492,8.6952,7.6952
# ai_product,300,top_quartile,inverse_maker_side,top_quartile_ex_decile,463,52.2678,47.7322,3.9675,2.9675
# ai_product,300,top_quartile,maker_side,bottom_decile,309,48.5437,43.6893,-5.0308,-6.0308
# ai_product,300,top_quartile,maker_side,bottom_quartile_ex_decile,473,49.6829,45.4545,-4.2086,-5.2086
# ai_product,300,top_quartile,maker_side,middle_two_quartiles,1532,48.7598,45.953,-4.1791,-5.1791
# ai_product,300,top_quartile,maker_side,top_decile,309,47.2492,41.7476,-8.6952,-9.6952
# ai_product,300,top_quartile,maker_side,top_quartile_ex_decile,463,46.6523,42.5486,-3.9675,-4.9675
# crypto,30,bottom_quartile,inverse_maker_side,bottom_decile,326,33.7423,28.6733,1.3782,0.3782
# crypto,30,bottom_quartile,inverse_maker_side,bottom_quartile_ex_decile,476,42.0168,37.4947,2.7526,1.7526
# crypto,30,bottom_quartile,inverse_maker_side,middle_two_quartiles,1601,40.3498,38.2261,2.0939,1.0939
# crypto,30,bottom_quartile,inverse_maker_side,top_decile,321,47.9751,42.3676,5.3534,4.3534
# crypto,30,bottom_quartile,inverse_maker_side,top_quartile_ex_decile,481,39.2931,34.7089,4.2138,3.2138
# crypto,30,bottom_quartile,maker_side,bottom_decile,326,57.6687,52.1472,-1.3782,-2.3782
# crypto,30,bottom_quartile,maker_side,bottom_quartile_ex_decile,476,52.7311,47.6891,-2.7526,-3.7526
# crypto,30,bottom_quartile,maker_side,middle_two_quartiles,1601,54.0912,51.5928,-2.0939,-3.0939
# crypto,30,bottom_quartile,maker_side,top_decile,321,47.9751,41.8925,-5.3534,-6.3534
# crypto,30,bottom_quartile,maker_side,top_quartile_ex_decile,481,56.341,51.8659,-4.2138,-5.2138
# crypto,30,middle_two_quartiles,inverse_maker_side,bottom_decile,661,40.3933,36.6831,0.1316,-0.8684
# crypto,30,middle_two_quartiles,inverse_maker_side,bottom_quartile_ex_decile,953,42.3924,39.3993,0.7398,-0.2602
# crypto,30,middle_two_quartiles,inverse_maker_side,middle_two_quartiles,3160,43.6392,41.9771,0.8717,-0.1283
# crypto,30,middle_two_quartiles,inverse_maker_side,top_decile,637,43.4851,40.263,2.1461,1.1461
# crypto,30,middle_two_quartiles,inverse_maker_side,top_quartile_ex_decile,955,42.199,39.1623,0.9305,-0.0695
# crypto,30,middle_two_quartiles,maker_side,bottom_decile,661,58.2451,54.5348,-0.1316,-1.1316
# crypto,30,middle_two_quartiles,maker_side,bottom_quartile_ex_decile,953,56.873,53.7251,-0.7398,-1.7398
# crypto,30,middle_two_quartiles,maker_side,middle_two_quartiles,3160,55.4747,53.6392,-0.8717,-1.8717
# crypto,30,middle_two_quartiles,maker_side,top_decile,637,56.044,52.029,-2.1461,-3.1461
# crypto,30,middle_two_quartiles,maker_side,top_quartile_ex_decile,955,57.0681,54.0812,-0.9305,-1.9305
# crypto,30,top_decile,inverse_maker_side,bottom_decile,128,42.9688,35.5273,-1.6143,-2.6143
# crypto,30,top_decile,inverse_maker_side,bottom_quartile_ex_decile,192,46.875,39.5833,-0.335,-1.335
# crypto,30,top_decile,inverse_maker_side,middle_two_quartiles,638,46.7085,42.5509,-0.4044,-1.4044
# crypto,30,top_decile,inverse_maker_side,top_decile,128,53.9062,44.5312,0.0627,-0.9373
# crypto,30,top_decile,inverse_maker_side,top_quartile_ex_decile,192,51.0417,44.7917,-0.7538,-1.7538
# crypto,30,top_decile,maker_side,bottom_decile,128,57.0312,48.8086,1.6143,0.6143
# crypto,30,top_decile,maker_side,bottom_quartile_ex_decile,192,53.125,45.8333,0.335,-0.665
# crypto,30,top_decile,maker_side,middle_two_quartiles,638,53.2915,49.2085,0.4044,-0.5956
# crypto,30,top_decile,maker_side,top_decile,128,46.0938,36.7188,-0.0627,-1.0627
# crypto,30,top_decile,maker_side,top_quartile_ex_decile,192,48.9583,41.1458,0.7538,-0.2462
# crypto,30,top_quartile,inverse_maker_side,bottom_decile,320,45.3125,39.6875,-1.4445,-2.4445
# crypto,30,top_quartile,inverse_maker_side,bottom_quartile_ex_decile,479,48.643,44.4572,-0.1312,-1.1312
# crypto,30,top_quartile,inverse_maker_side,middle_two_quartiles,1597,44.6462,42.1713,-0.187,-1.187
# crypto,30,top_quartile,inverse_maker_side,top_decile,320,50.625,45.3125,-0.668,-1.668
# crypto,30,top_quartile,inverse_maker_side,top_quartile_ex_decile,479,41.7537,37.3695,-1.5542,-2.5542
# crypto,30,top_quartile,maker_side,bottom_decile,320,54.6875,49.2109,1.4445,0.4445
# crypto,30,top_quartile,maker_side,bottom_quartile_ex_decile,479,51.357,46.7641,0.1312,-0.8688
# crypto,30,top_quartile,maker_side,middle_two_quartiles,1597,55.3538,52.9086,0.187,-0.813
# crypto,30,top_quartile,maker_side,top_decile,320,49.375,43.4219,0.668,-0.332
# crypto,30,top_quartile,maker_side,top_quartile_ex_decile,479,58.2463,53.5438,1.5542,0.5542
# ```

# %% [markdown]
# ## Figures
#
# ![block_b_volume_top_decile_300s_inverse](figs/block_b_volume_top_decile_300s_inverse.png)
