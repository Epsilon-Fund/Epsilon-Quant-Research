# %% [markdown]
# # Block B Sports Analysis
#
# Generated by `scripts/dali_tfi_deep_dive.py`.

# %% [markdown]
# ## Hit-Rate By Magnitude
#
# Game start time is not available in the local market metadata, so pre-game vs in-game segmentation is left as a TODO rather than inferred from resolution time.
#
# ```csv
# horizon_seconds,sports_game_phase,sign_convention,magnitude_bucket,n_obs,hit_rate_pct,hit_rate_ci_low_pct,mean_return_cents
# 30,unknown_start_time,inverse_maker_side,bottom_decile,2291,46.399,44.2809,1.7265
# 30,unknown_start_time,inverse_maker_side,bottom_quartile_ex_decile,3434,46.5347,44.901,0.9497
# 30,unknown_start_time,inverse_maker_side,middle_two_quartiles,11448,49.572,48.6373,0.6382
# 30,unknown_start_time,inverse_maker_side,top_decile,2290,44.2358,42.3352,0.9485
# 30,unknown_start_time,inverse_maker_side,top_quartile_ex_decile,3435,46.2591,44.583,0.9366
# 30,unknown_start_time,maker_side,bottom_decile,2291,41.5539,39.5024,-1.7265
# 30,unknown_start_time,maker_side,bottom_quartile_ex_decile,3434,38.2353,36.6045,-0.9497
# 30,unknown_start_time,maker_side,middle_two_quartiles,11448,39.3082,38.3897,-0.6382
# 30,unknown_start_time,maker_side,top_decile,2290,44.7598,42.7926,-0.9485
# 30,unknown_start_time,maker_side,top_quartile_ex_decile,3435,40.8151,39.286,-0.9366
# 120,unknown_start_time,inverse_maker_side,bottom_decile,2205,46.8027,44.6927,1.7743
# 120,unknown_start_time,inverse_maker_side,bottom_quartile_ex_decile,3305,46.7171,44.9319,0.8676
# 120,unknown_start_time,inverse_maker_side,middle_two_quartiles,11017,49.9501,49.0324,0.6049
# 120,unknown_start_time,inverse_maker_side,top_decile,2204,43.8748,41.8784,0.4655
# 120,unknown_start_time,inverse_maker_side,top_quartile_ex_decile,3307,47.1727,45.6305,0.5769
# 120,unknown_start_time,maker_side,bottom_decile,2205,43.1746,41.0431,-1.7743
# 120,unknown_start_time,maker_side,bottom_quartile_ex_decile,3305,37.9728,36.323,-0.8676
# 120,unknown_start_time,maker_side,middle_two_quartiles,11017,39.1032,38.3178,-0.6049
# 120,unknown_start_time,maker_side,top_decile,2204,46.8693,44.8491,-0.4655
# 120,unknown_start_time,maker_side,top_quartile_ex_decile,3307,41.5785,39.7021,-0.5769
# 300,unknown_start_time,inverse_maker_side,bottom_decile,2121,48.9863,47.1228,1.9363
# 300,unknown_start_time,inverse_maker_side,bottom_quartile_ex_decile,3181,48.4753,46.8241,1.0829
# 300,unknown_start_time,inverse_maker_side,middle_two_quartiles,10595,50.2973,49.2631,0.5482
# 300,unknown_start_time,inverse_maker_side,top_decile,2121,44.2716,42.2171,0.4881
# 300,unknown_start_time,inverse_maker_side,top_quartile_ex_decile,3183,47.4081,45.8208,0.9272
# 300,unknown_start_time,maker_side,bottom_decile,2121,42.9514,40.8298,-1.9363
# 300,unknown_start_time,maker_side,bottom_quartile_ex_decile,3181,39.1072,37.5024,-1.0829
# 300,unknown_start_time,maker_side,middle_two_quartiles,10595,39.7829,38.8575,-0.5482
# 300,unknown_start_time,maker_side,top_decile,2121,47.7133,45.7555,-0.4881
# 300,unknown_start_time,maker_side,top_quartile_ex_decile,3183,43.0726,41.4538,-0.9272
# ```

# %% [markdown]
# ## League Breakdown
#
# ```csv
# sports_league,horizon_seconds,sign_convention,magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents
# mlb,30,maker_side,bottom_decile,346,45.3757,-0.9656
# mlb,30,inverse_maker_side,bottom_decile,346,42.4855,0.9656
# mlb,30,maker_side,bottom_quartile_ex_decile,515,45.8252,-0.7212
# mlb,30,inverse_maker_side,bottom_quartile_ex_decile,515,42.1359,0.7212
# mlb,30,maker_side,middle_two_quartiles,1722,46.3995,-0.4055
# mlb,30,inverse_maker_side,middle_two_quartiles,1722,44.0767,0.4055
# mlb,30,maker_side,top_decile,345,48.9855,-0.0888
# mlb,30,inverse_maker_side,top_decile,345,45.2174,0.0888
# mlb,30,maker_side,top_quartile_ex_decile,516,45.5426,-0.8437
# mlb,30,inverse_maker_side,top_quartile_ex_decile,516,46.124,0.8437
# mlb,120,maker_side,bottom_decile,338,46.4497,-0.5958
# mlb,120,inverse_maker_side,bottom_decile,338,46.4497,0.5958
# mlb,120,maker_side,bottom_quartile_ex_decile,507,44.1815,-1.2709
# mlb,120,inverse_maker_side,bottom_quartile_ex_decile,507,42.8008,1.2709
# mlb,120,maker_side,middle_two_quartiles,1688,49.4076,0.3835
# mlb,120,inverse_maker_side,middle_two_quartiles,1688,42.4171,-0.3835
# mlb,120,maker_side,top_decile,338,50.5917,-0.6078
# mlb,120,inverse_maker_side,top_decile,338,45.2663,0.6078
# mlb,120,maker_side,top_quartile_ex_decile,507,50.6903,0.5605
# mlb,120,inverse_maker_side,top_quartile_ex_decile,507,42.2091,-0.5605
# mlb,300,maker_side,bottom_decile,331,42.5982,-2.0624
# mlb,300,inverse_maker_side,bottom_decile,331,52.2659,2.0624
# mlb,300,maker_side,bottom_quartile_ex_decile,492,46.3415,-1.2214
# mlb,300,inverse_maker_side,bottom_quartile_ex_decile,492,43.4959,1.2214
# mlb,300,maker_side,middle_two_quartiles,1643,48.6306,-0.4461
# mlb,300,inverse_maker_side,middle_two_quartiles,1643,44.3701,0.4461
# mlb,300,maker_side,top_decile,329,54.1033,0.3962
# mlb,300,inverse_maker_side,top_decile,329,41.0334,-0.3962
# mlb,300,maker_side,top_quartile_ex_decile,494,50.6073,-0.1483
# mlb,300,inverse_maker_side,top_quartile_ex_decile,494,45.1417,0.1483
# nba,30,maker_side,bottom_decile,1196,38.3779,-0.9364
# nba,30,inverse_maker_side,bottom_decile,1196,51.4214,0.9364
# nba,30,maker_side,bottom_quartile_ex_decile,1793,33.9654,-0.1773
# nba,30,inverse_maker_side,bottom_quartile_ex_decile,1793,51.5337,0.1773
# nba,30,maker_side,middle_two_quartiles,5972,34.0757,-0.3206
# nba,30,inverse_maker_side,middle_two_quartiles,5972,53.6169,0.3206
# nba,30,maker_side,top_decile,1195,39.4979,-1.2542
# nba,30,inverse_maker_side,top_decile,1195,44.7699,1.2542
# nba,30,maker_side,top_quartile_ex_decile,1792,37.5558,-1.3046
# nba,30,inverse_maker_side,top_quartile_ex_decile,1792,50.2232,1.3046
# nba,120,maker_side,bottom_decile,1158,39.1192,-1.1682
# nba,120,inverse_maker_side,bottom_decile,1158,51.7271,1.1682
# nba,120,maker_side,bottom_quartile_ex_decile,1729,32.7935,-0.1147
# nba,120,inverse_maker_side,bottom_quartile_ex_decile,1729,51.3592,0.1147
# nba,120,maker_side,middle_two_quartiles,5774,33.0793,-0.5004
# nba,120,inverse_maker_side,middle_two_quartiles,5774,54.2605,0.5004
# nba,120,maker_side,top_decile,1155,38.7013,-1.1934
# nba,120,inverse_maker_side,top_decile,1155,46.1472,1.1934
# nba,120,maker_side,top_quartile_ex_decile,1732,37.9908,-0.9317
# nba,120,inverse_maker_side,top_quartile_ex_decile,1732,51.5012,0.9317
# nba,300,maker_side,bottom_decile,1126,38.8099,-0.9625
# nba,300,inverse_maker_side,bottom_decile,1126,53.0195,0.9625
# nba,300,maker_side,bottom_quartile_ex_decile,1690,33.9645,-0.406
# nba,300,inverse_maker_side,bottom_quartile_ex_decile,1690,52.2485,0.406
# nba,300,maker_side,middle_two_quartiles,5624,33.5171,-0.3341
# nba,300,inverse_maker_side,middle_two_quartiles,5624,54.7831,0.3341
# nba,300,maker_side,top_decile,1126,42.4512,-1.26
# nba,300,inverse_maker_side,top_decile,1126,45.3819,1.26
# nba,300,maker_side,top_quartile_ex_decile,1688,36.6114,-0.9763
# nba,300,inverse_maker_side,top_quartile_ex_decile,1688,52.1327,0.9763
# nhl,30,maker_side,bottom_decile,301,33.2226,-3.6609
# nhl,30,inverse_maker_side,bottom_decile,301,44.5183,3.6609
# nhl,30,maker_side,bottom_quartile_ex_decile,446,41.2556,-5.463
# nhl,30,inverse_maker_side,bottom_quartile_ex_decile,446,43.9462,5.463
# nhl,30,maker_side,middle_two_quartiles,1490,43.2215,-2.7828
# nhl,30,inverse_maker_side,middle_two_quartiles,1490,44.8993,2.7828
# nhl,30,maker_side,top_decile,300,45.0,-1.1582
# nhl,30,inverse_maker_side,top_decile,300,39.6667,1.1582
# nhl,30,maker_side,top_quartile_ex_decile,449,44.5434,-0.8493
# nhl,30,inverse_maker_side,top_quartile_ex_decile,449,44.098,0.8493
# nhl,120,maker_side,bottom_decile,279,39.4265,-4.1707
# nhl,120,inverse_maker_side,bottom_decile,279,43.3692,4.1707
# nhl,120,maker_side,bottom_quartile_ex_decile,420,41.6667,-6.4037
# nhl,120,inverse_maker_side,bottom_quartile_ex_decile,420,42.8571,6.4037
# nhl,120,maker_side,middle_two_quartiles,1392,43.5345,-2.4741
# nhl,120,inverse_maker_side,middle_two_quartiles,1392,43.75,2.4741
# nhl,120,maker_side,top_decile,279,48.7455,1.3808
# nhl,120,inverse_maker_side,top_decile,279,40.5018,-1.3808
# nhl,120,maker_side,top_quartile_ex_decile,418,43.0622,-1.7116
# nhl,120,inverse_maker_side,top_quartile_ex_decile,418,45.2153,1.7116
# nhl,300,maker_side,bottom_decile,258,39.5349,-7.0088
# nhl,300,inverse_maker_side,bottom_decile,258,50.0,7.0088
# nhl,300,maker_side,bottom_quartile_ex_decile,390,45.3846,-5.0571
# nhl,300,inverse_maker_side,bottom_quartile_ex_decile,390,45.1282,5.0571
# nhl,300,maker_side,middle_two_quartiles,1284,44.5483,-2.8059
# nhl,300,inverse_maker_side,middle_two_quartiles,1284,45.0156,2.8059
# nhl,300,maker_side,top_decile,258,43.0233,-1.9789
# nhl,300,inverse_maker_side,top_decile,258,44.186,1.9789
# nhl,300,maker_side,top_quartile_ex_decile,386,42.228,-2.7863
# nhl,300,inverse_maker_side,top_quartile_ex_decile,386,50.0,2.7863
# other_sports,30,maker_side,bottom_decile,312,42.9487,-1.212
# other_sports,30,inverse_maker_side,bottom_decile,312,46.4744,1.212
# other_sports,30,maker_side,bottom_quartile_ex_decile,467,39.4004,-1.2599
# other_sports,30,inverse_maker_side,bottom_quartile_ex_decile,467,33.6188,1.2599
# other_sports,30,maker_side,middle_two_quartiles,1557,47.4631,-0.0704
# other_sports,30,inverse_maker_side,middle_two_quartiles,1557,40.6551,0.0704
# other_sports,30,maker_side,top_decile,312,44.2308,-1.144
# other_sports,30,inverse_maker_side,top_decile,312,48.3974,1.144
# other_sports,30,maker_side,top_quartile_ex_decile,467,45.3961,-0.2312
# other_sports,30,inverse_maker_side,top_quartile_ex_decile,467,39.6146,0.2312
# other_sports,120,maker_side,bottom_decile,298,47.3154,0.1515
# other_sports,120,inverse_maker_side,bottom_decile,298,43.6242,-0.1515
# other_sports,120,maker_side,bottom_quartile_ex_decile,445,39.1011,-0.0824
# other_sports,120,inverse_maker_side,bottom_quartile_ex_decile,445,38.6517,0.0824
# other_sports,120,maker_side,middle_two_quartiles,1483,48.5502,0.0204
# other_sports,120,inverse_maker_side,middle_two_quartiles,1483,40.8631,-0.0204
# other_sports,120,maker_side,top_decile,298,48.3221,-0.8933
# other_sports,120,inverse_maker_side,top_decile,298,46.3087,0.8933
# other_sports,120,maker_side,top_quartile_ex_decile,445,47.191,0.4887
# other_sports,120,inverse_maker_side,top_quartile_ex_decile,445,42.0225,-0.4887
# other_sports,300,maker_side,bottom_decile,276,48.1884,0.3804
# other_sports,300,inverse_maker_side,bottom_decile,276,42.7536,-0.3804
# other_sports,300,maker_side,bottom_quartile_ex_decile,413,44.0678,-0.1507
# other_sports,300,inverse_maker_side,bottom_quartile_ex_decile,413,37.5303,0.1507
# other_sports,300,maker_side,middle_two_quartiles,1374,50.8006,0.201
# other_sports,300,inverse_maker_side,middle_two_quartiles,1374,40.6114,-0.201
# other_sports,300,maker_side,top_decile,276,45.2899,0.0103
# other_sports,300,inverse_maker_side,top_decile,276,48.5507,-0.0103
# other_sports,300,maker_side,top_quartile_ex_decile,415,54.2169,0.3878
# other_sports,300,inverse_maker_side,top_quartile_ex_decile,415,40.241,-0.3878
# ```

# %% [markdown]
# ## Figures
#
# ![block_b_sports_league_top_decile_inverse](figs/block_b_sports_league_top_decile_inverse.png)
