# %% [markdown]
# # Block B Resolution Sweep
#
# Generated by `scripts/dali_tfi_deep_dive.py`.

# %% [markdown]
# ## Top-Decile Rows
#
# ```csv
# family_label,exclude_last_seconds,horizon_seconds,sign_convention,magnitude_bucket,n_obs,hit_rate_pct,hit_rate_ci_low_pct,mean_return_cents,net_edge_after_1tick_cents
# ai_product,0,30,inverse_maker_side,top_decile,1486,48.6541,46.1642,4.5404,3.5404
# ai_product,0,30,maker_side,top_decile,1486,48.4522,45.6898,-4.5404,-5.5404
# ai_product,0,120,inverse_maker_side,top_decile,1343,49.0692,46.573,5.159,4.159
# ai_product,0,120,maker_side,top_decile,1343,49.1437,46.6121,-5.159,-6.159
# ai_product,0,300,inverse_maker_side,top_decile,1234,50.7293,48.4603,5.6203,4.6203
# ai_product,0,300,maker_side,top_decile,1234,48.2172,44.8947,-5.6203,-6.6203
# ai_product,60,30,inverse_maker_side,top_decile,1486,48.6541,46.2315,4.5404,3.5404
# ai_product,60,30,maker_side,top_decile,1486,48.4522,45.8597,-4.5404,-5.5404
# ai_product,60,120,inverse_maker_side,top_decile,1343,49.0692,46.3887,5.159,4.159
# ai_product,60,120,maker_side,top_decile,1343,49.1437,46.4985,-5.159,-6.159
# ai_product,60,300,inverse_maker_side,top_decile,1234,50.7293,48.1746,5.6203,4.6203
# ai_product,60,300,maker_side,top_decile,1234,48.2172,45.6199,-5.6203,-6.6203
# ai_product,120,30,inverse_maker_side,top_decile,1486,48.6541,46.2315,4.5404,3.5404
# ai_product,120,30,maker_side,top_decile,1486,48.4522,46.1642,-4.5404,-5.5404
# ai_product,120,120,inverse_maker_side,top_decile,1343,49.0692,46.1653,5.159,4.159
# ai_product,120,120,maker_side,top_decile,1343,49.1437,46.8708,-5.159,-6.159
# ai_product,120,300,inverse_maker_side,top_decile,1234,50.7293,48.0126,5.6203,4.6203
# ai_product,120,300,maker_side,top_decile,1234,48.2172,45.3383,-5.6203,-6.6203
# ai_product,300,30,inverse_maker_side,top_decile,1486,48.6541,46.4334,4.5404,3.5404
# ai_product,300,30,maker_side,top_decile,1486,48.4522,45.7604,-4.5404,-5.5404
# ai_product,300,120,inverse_maker_side,top_decile,1343,49.0692,46.4594,5.159,4.159
# ai_product,300,120,maker_side,top_decile,1343,49.1437,46.1262,-5.159,-6.159
# ai_product,300,300,inverse_maker_side,top_decile,1234,50.7293,47.812,5.6203,4.6203
# ai_product,300,300,maker_side,top_decile,1234,48.2172,45.4194,-5.6203,-6.6203
# ai_product,600,30,inverse_maker_side,top_decile,1485,48.6869,45.8906,4.5435,3.5435
# ai_product,600,30,maker_side,top_decile,1485,48.4175,46.1953,-4.5435,-5.5435
# ai_product,600,120,inverse_maker_side,top_decile,1343,49.0692,46.4985,5.159,4.159
# ai_product,600,120,maker_side,top_decile,1343,49.1437,46.6121,-5.159,-6.159
# ai_product,600,300,inverse_maker_side,top_decile,1234,50.7293,47.7654,5.6203,4.6203
# ai_product,600,300,maker_side,top_decile,1234,48.2172,45.2573,-5.6203,-6.6203
# ai_product,1200,30,inverse_maker_side,top_decile,1485,48.6869,45.8906,4.5435,3.5435
# ai_product,1200,30,maker_side,top_decile,1485,48.4175,45.7559,-4.5435,-5.5435
# ai_product,1200,120,inverse_maker_side,top_decile,1343,49.0692,46.6083,5.159,4.159
# ai_product,1200,120,maker_side,top_decile,1343,49.1437,46.6828,-5.159,-6.159
# ai_product,1200,300,inverse_maker_side,top_decile,1234,50.7293,48.2172,5.6203,4.6203
# ai_product,1200,300,maker_side,top_decile,1234,48.2172,45.5814,-5.6203,-6.6203
# ai_product,1800,30,inverse_maker_side,top_decile,1485,48.6869,46.1279,4.5435,3.5435
# ai_product,1800,30,maker_side,top_decile,1485,48.4175,46.1279,-4.5435,-5.5435
# ai_product,1800,120,inverse_maker_side,top_decile,1343,49.0692,46.236,5.159,4.159
# ai_product,1800,120,maker_side,top_decile,1343,49.1437,46.6828,-5.159,-6.159
# ai_product,1800,300,inverse_maker_side,top_decile,1234,50.7293,47.9741,5.6203,4.6203
# ai_product,1800,300,maker_side,top_decile,1234,48.2172,45.4619,-5.6203,-6.6203
# ai_product,3600,30,inverse_maker_side,top_decile,1485,48.6869,46.2946,4.5435,3.5435
# ai_product,3600,30,maker_side,top_decile,1485,48.4175,45.8906,-4.5435,-5.5435
# ai_product,3600,120,inverse_maker_side,top_decile,1342,49.1058,46.3804,5.1639,4.1639
# ai_product,3600,120,maker_side,top_decile,1342,49.1058,46.6077,-5.1639,-6.1639
# ai_product,3600,300,inverse_maker_side,top_decile,1234,50.6483,47.9741,5.5345,4.5345
# ai_product,3600,300,maker_side,top_decile,1234,48.2982,45.5429,-5.5345,-6.5345
# ai_product,7200,30,inverse_maker_side,top_decile,1484,48.7197,46.3258,4.5479,3.5479
# ai_product,7200,30,maker_side,top_decile,1484,48.3827,45.7547,-4.5479,-5.5479
# ai_product,7200,120,inverse_maker_side,top_decile,1342,49.1058,46.494,5.1639,4.1639
# ai_product,7200,120,maker_side,top_decile,1342,49.1058,46.5723,-5.1639,-6.1639
# ai_product,7200,300,inverse_maker_side,top_decile,1234,50.6483,47.5263,5.5284,4.5284
# ai_product,7200,300,maker_side,top_decile,1234,48.2982,45.8671,-5.5284,-6.5284
# crypto,0,30,inverse_maker_side,top_decile,3818,36.8256,35.385,-1.7071,-2.7071
# crypto,0,30,maker_side,top_decile,3818,62.8339,61.2349,1.7071,0.7071
# crypto,0,120,inverse_maker_side,top_decile,3182,28.7555,27.1527,-7.9507,-8.9507
# crypto,0,120,maker_side,top_decile,3182,70.8674,69.1224,7.9507,6.9507
# crypto,0,300,inverse_maker_side,top_decile,1860,31.0753,28.9503,-6.3743,-7.3743
# crypto,0,300,maker_side,top_decile,1860,68.871,66.7204,6.3743,5.3743
# crypto,60,30,inverse_maker_side,top_decile,3638,37.9329,36.3517,-1.359,-2.359
# crypto,60,30,maker_side,top_decile,3638,61.7097,60.1979,1.359,0.359
# crypto,60,120,inverse_maker_side,top_decile,3182,28.7555,27.3876,-7.9507,-8.9507
# crypto,60,120,maker_side,top_decile,3182,70.8674,69.1986,7.9507,6.9507
# crypto,60,300,inverse_maker_side,top_decile,1860,31.0753,29.1398,-6.3743,-7.3743
# crypto,60,300,maker_side,top_decile,1860,68.871,66.9355,6.3743,5.3743
# crypto,120,30,inverse_maker_side,top_decile,3241,39.0003,37.4074,-0.9547,-1.9547
# crypto,120,30,maker_side,top_decile,3241,60.6294,59.241,0.9547,-0.0453
# crypto,120,120,inverse_maker_side,top_decile,3182,28.7555,27.3727,-7.9507,-8.9507
# crypto,120,120,maker_side,top_decile,3182,70.8674,69.2795,7.9507,6.9507
# crypto,120,300,inverse_maker_side,top_decile,1860,31.0753,28.7352,-6.3743,-7.3743
# crypto,120,300,maker_side,top_decile,1860,68.871,66.664,6.3743,5.3743
# crypto,300,30,inverse_maker_side,top_decile,1950,45.6923,43.4603,1.5626,0.5626
# crypto,300,30,maker_side,top_decile,1950,53.4872,51.5359,-1.5626,-2.5626
# crypto,300,120,inverse_maker_side,top_decile,1942,38.0536,36.0968,-1.375,-2.375
# crypto,300,120,maker_side,top_decile,1942,61.277,59.0358,1.375,0.375
# crypto,300,300,inverse_maker_side,top_decile,1860,31.0753,28.9247,-6.3743,-7.3743
# crypto,300,300,maker_side,top_decile,1860,68.871,66.5591,6.3743,5.3743
# crypto,600,30,inverse_maker_side,top_decile,1277,46.5153,43.9311,2.1735,1.1735
# crypto,600,30,maker_side,top_decile,1277,52.2318,49.7631,-2.1735,-3.1735
# ```

# %% [markdown]
# ## Figures
#
# ![block_b_resolution_sweep_top_decile_300s](figs/block_b_resolution_sweep_top_decile_300s.png)
