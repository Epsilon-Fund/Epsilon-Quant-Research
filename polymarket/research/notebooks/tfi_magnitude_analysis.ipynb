# %% [markdown]
# # TFI Magnitude Analysis
#
# Generated by `scripts/dali_tfi_magnitude_analysis.py`.
#
# Sign convention is not established from live CLOB yet, so this notebook reports both `maker_side` and `inverse_maker_side`.

# %% [markdown]
# ## ai_product | 30s | inverse_maker_side
#
# Hit rate is roughly flat, EV rises (+0.88c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1486,46.5007,3.6651,0.0,0.151
# bottom_quartile_ex_decile,2228,46.8582,3.5843,0.0,0.1389
# middle_two_quartiles,7448,46.3077,3.6634,0.0,0.1495
# top_quartile_ex_decile,2203,47.6169,3.4232,0.0,0.1446
# top_decile,1485,48.6869,4.5435,0.0,0.1669

# %% [markdown]
# ## ai_product | 30s | maker_side
#
# Mixed pattern: hit delta 2.7pp, EV delta -0.88c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1486,45.7604,-3.6651,0.0,-0.151
# bottom_quartile_ex_decile,2228,47.2621,-3.5843,0.0,-0.1389
# middle_two_quartiles,7448,47.355,-3.6634,0.0,-0.1495
# top_quartile_ex_decile,2203,48.2524,-3.4232,0.0,-0.1446
# top_decile,1485,48.4175,-4.5435,0.0,-0.1669

# %% [markdown]
# ## ai_product | 120s | inverse_maker_side
#
# Hit rate is roughly flat, EV rises (+2.03c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1344,47.3214,3.1314,0.0,0.1234
# bottom_quartile_ex_decile,2017,45.4636,2.5582,-0.0,0.0983
# middle_two_quartiles,6712,45.9774,3.3773,0.0,0.1357
# top_quartile_ex_decile,2010,47.5622,3.8706,0.0,0.1535
# top_decile,1343,49.0692,5.159,0.0,0.1943

# %% [markdown]
# ## ai_product | 120s | maker_side
#
# Mixed pattern: hit delta 2.6pp, EV delta -2.03c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1344,46.503,-3.1314,0.0,-0.1234
# bottom_quartile_ex_decile,2017,50.7685,-2.5582,0.0,-0.0983
# middle_two_quartiles,6712,49.3743,-3.3773,0.0,-0.1357
# top_quartile_ex_decile,2010,49.204,-3.8706,0.0,-0.1535
# top_decile,1343,49.1437,-5.159,0.0,-0.1943

# %% [markdown]
# ## ai_product | 300s | inverse_maker_side
#
# Hit rate is roughly flat, EV rises (+1.57c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1234,48.1361,4.0508,0.0,0.1527
# bottom_quartile_ex_decile,1851,45.5429,2.0457,-0.0,0.0825
# middle_two_quartiles,6169,46.9768,3.6872,0.0,0.1449
# top_quartile_ex_decile,1851,49.1086,5.0268,0.0,0.1998
# top_decile,1234,50.7293,5.6203,0.0,0.2195

# %% [markdown]
# ## ai_product | 300s | maker_side
#
# Mixed pattern: hit delta 0.5pp, EV delta -1.57c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1234,47.731,-4.0508,0.0,-0.1527
# bottom_quartile_ex_decile,1851,50.9454,-2.0457,0.0,-0.0825
# middle_two_quartiles,6169,48.9544,-3.6872,0.0,-0.1449
# top_quartile_ex_decile,1851,48.5143,-5.0268,0.0,-0.1998
# top_decile,1234,48.2172,-5.6203,-0.0,-0.2195

# %% [markdown]
# ## daily_crypto_up_down | 30s | inverse_maker_side
#
# Hit rate rises with magnitude (+6.3pp): informative-flow pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1277,40.1723,0.3397,-0.1982,0.0256
# bottom_quartile_ex_decile,1915,43.3943,0.9325,-0.1,0.0777
# middle_two_quartiles,6382,43.3093,0.9303,-0.0757,0.0742
# top_quartile_ex_decile,1915,40.7311,1.0156,-0.22,0.0729
# top_decile,1277,46.5153,2.1735,-0.0248,0.1418

# %% [markdown]
# ## daily_crypto_up_down | 30s | maker_side
#
# Mixed pattern: hit delta -4.7pp, EV delta -1.83c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1277,56.9303,-0.3397,0.1982,-0.0256
# bottom_quartile_ex_decile,1915,54.9347,-0.9325,0.1,-0.0777
# middle_two_quartiles,6382,54.8417,-0.9303,0.0757,-0.0742
# top_quartile_ex_decile,1915,57.859,-1.0156,0.22,-0.0729
# top_decile,1277,52.2318,-2.1735,0.0248,-0.1418

# %% [markdown]
# ## daily_crypto_up_down | 120s | inverse_maker_side
#
# Hit rate and EV are roughly flat: weak or artifact-prone pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1272,39.0723,0.4432,-0.5598,0.0268
# bottom_quartile_ex_decile,1907,39.9056,0.0752,-0.5742,0.0051
# middle_two_quartiles,6358,39.525,-0.2352,-0.4966,-0.0163
# top_quartile_ex_decile,1907,39.8532,-0.5806,-0.6592,-0.0404
# top_decile,1272,41.7453,0.1214,-0.3045,0.0079

# %% [markdown]
# ## daily_crypto_up_down | 120s | maker_side
#
# Hit rate and EV are roughly flat: weak or artifact-prone pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1272,59.7484,-0.4432,0.5598,-0.0268
# bottom_quartile_ex_decile,1907,59.1505,-0.0752,0.5742,-0.0051
# middle_two_quartiles,6358,59.3268,0.2352,0.4966,0.0163
# top_quartile_ex_decile,1907,59.5176,0.5806,0.6592,0.0404
# top_decile,1272,57.2327,-0.1214,0.3045,-0.0079

# %% [markdown]
# ## daily_crypto_up_down | 300s | inverse_maker_side
#
# Hit rate and EV are roughly flat: weak or artifact-prone pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1265,35.0988,-2.6233,-1.6596,-0.1497
# bottom_quartile_ex_decile,1893,36.6086,-2.6126,-1.8761,-0.1515
# middle_two_quartiles,6303,32.0324,-3.5112,-1.9281,-0.2048
# top_quartile_ex_decile,1892,33.351,-3.4588,-2.2099,-0.1903
# top_decile,1262,34.3106,-3.0284,-1.8696,-0.1627

# %% [markdown]
# ## daily_crypto_up_down | 300s | maker_side
#
# Hit rate and EV are roughly flat: weak or artifact-prone pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1265,63.5573,2.6233,1.6596,0.1497
# bottom_quartile_ex_decile,1893,62.2293,2.6126,1.8761,0.1515
# middle_two_quartiles,6303,67.2537,3.5112,1.9281,0.2048
# top_quartile_ex_decile,1892,66.2791,3.4588,2.2099,0.1903
# top_decile,1262,65.6101,3.0284,1.8696,0.1627

# %% [markdown]
# ## daily_equity_index | 30s | inverse_maker_side
#
# Hit rate is roughly flat, EV rises (+1.43c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1450,47.2414,5.2091,0.0,0.2135
# bottom_quartile_ex_decile,2446,47.6697,3.2691,0.0,0.149
# middle_two_quartiles,7000,47.7,3.9236,0.0,0.1837
# top_quartile_ex_decile,2150,48.2326,3.8357,0.0,0.1684
# top_decile,1450,47.6552,6.6344,0.0,0.2609

# %% [markdown]
# ## daily_equity_index | 30s | maker_side
#
# Mixed pattern: hit delta 2.8pp, EV delta -1.43c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1450,47.1034,-5.2091,0.0,-0.2135
# bottom_quartile_ex_decile,2446,45.7073,-3.2691,0.0,-0.149
# middle_two_quartiles,7000,46.9429,-3.9236,0.0,-0.1837
# top_quartile_ex_decile,2150,48.7442,-3.8357,0.0,-0.1684
# top_decile,1450,49.8621,-6.6344,0.0,-0.2609

# %% [markdown]
# ## daily_equity_index | 120s | inverse_maker_side
#
# Hit rate is roughly flat, EV rises (+0.63c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1413,48.4076,5.3975,0.0,0.2274
# bottom_quartile_ex_decile,2379,47.4149,2.6928,0.0,0.126
# middle_two_quartiles,6801,48.4488,4.3977,0.0,0.1942
# top_quartile_ex_decile,2118,48.4891,4.6691,0.0,0.2012
# top_decile,1413,49.1154,6.0288,0.0,0.2494

# %% [markdown]
# ## daily_equity_index | 120s | maker_side
#
# Mixed pattern: hit delta 1.2pp, EV delta -0.63c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1413,48.3369,-5.3975,0.0,-0.2274
# bottom_quartile_ex_decile,2379,48.8861,-2.6928,0.0,-0.126
# middle_two_quartiles,6801,48.1841,-4.3977,0.0,-0.1942
# top_quartile_ex_decile,2118,49.2918,-4.6691,0.0,-0.2012
# top_decile,1413,49.54,-6.0288,0.0,-0.2494

# %% [markdown]
# ## daily_equity_index | 300s | inverse_maker_side
#
# Hit rate is roughly flat, EV rises (+1.78c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1376,47.2384,3.3593,-0.0,0.1465
# bottom_quartile_ex_decile,2336,47.6455,3.8672,-0.0,0.18
# middle_two_quartiles,6628,49.0495,4.839,0.0,0.2079
# top_quartile_ex_decile,2037,50.4664,5.5174,0.0,0.223
# top_decile,1376,47.093,5.1352,-0.0129,0.2178

# %% [markdown]
# ## daily_equity_index | 300s | maker_side
#
# Mixed pattern: hit delta 0.4pp, EV delta -1.78c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,1376,51.0901,-3.3593,0.0,-0.1465
# bottom_quartile_ex_decile,2336,50.3425,-3.8672,0.0,-0.18
# middle_two_quartiles,6628,48.8383,-4.839,0.0,-0.2079
# top_quartile_ex_decile,2037,48.6009,-5.5174,-0.0,-0.223
# top_decile,1376,51.5262,-5.1352,0.0129,-0.2178

# %% [markdown]
# ## sports_game_lines | 30s | inverse_maker_side
#
# Mixed pattern: hit delta -2.2pp, EV delta -0.78c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,2291,46.399,1.7265,0.0,0.1192
# bottom_quartile_ex_decile,3434,46.5347,0.9497,0.0,0.0817
# middle_two_quartiles,11448,49.572,0.6382,0.0,0.0534
# top_quartile_ex_decile,3435,46.2591,0.9366,0.0,0.0883
# top_decile,2290,44.2358,0.9485,0.0,0.0777

# %% [markdown]
# ## sports_game_lines | 30s | maker_side
#
# Hit rate is roughly flat, EV rises (+0.78c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,2291,41.5539,-1.7265,0.0,-0.1192
# bottom_quartile_ex_decile,3434,38.2353,-0.9497,0.0,-0.0817
# middle_two_quartiles,11448,39.3082,-0.6382,0.0,-0.0534
# top_quartile_ex_decile,3435,40.8151,-0.9366,0.0,-0.0883
# top_decile,2290,44.7598,-0.9485,0.0,-0.0777

# %% [markdown]
# ## sports_game_lines | 120s | inverse_maker_side
#
# Mixed pattern: hit delta -2.9pp, EV delta -1.31c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,2205,46.8027,1.7743,0.0,0.1157
# bottom_quartile_ex_decile,3305,46.7171,0.8676,0.0,0.0722
# middle_two_quartiles,11021,49.9501,0.6047,0.0,0.0495
# top_quartile_ex_decile,3303,47.1692,0.5776,0.0,0.0515
# top_decile,2204,43.8748,0.4655,0.0,0.0414

# %% [markdown]
# ## sports_game_lines | 120s | maker_side
#
# Hit rate is roughly flat, EV rises (+1.31c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,2205,43.1746,-1.7743,0.0,-0.1157
# bottom_quartile_ex_decile,3305,37.9728,-0.8676,0.0,-0.0722
# middle_two_quartiles,11021,39.1072,-0.6047,0.0,-0.0495
# top_quartile_ex_decile,3303,41.5683,-0.5776,0.0,-0.0515
# top_decile,2204,46.8693,-0.4655,0.0,-0.0414

# %% [markdown]
# ## sports_game_lines | 300s | inverse_maker_side
#
# Mixed pattern: hit delta -4.7pp, EV delta -1.45c.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,2121,48.9863,1.9363,0.0,0.1205
# bottom_quartile_ex_decile,3181,48.4753,1.0829,0.0,0.0807
# middle_two_quartiles,10611,50.3251,0.5505,0.0,0.0442
# top_quartile_ex_decile,3168,47.2854,0.921,0.0,0.0805
# top_decile,2120,44.2925,0.4884,0.0,0.0409

# %% [markdown]
# ## sports_game_lines | 300s | maker_side
#
# Hit rate is roughly flat, EV rises (+1.45c): tail/asymmetry pattern.
#
# magnitude_bucket,n_obs,hit_rate_pct,mean_return_cents,median_return_cents,return_sharpe_like
# bottom_decile,2121,42.9514,-1.9363,0.0,-0.1205
# bottom_quartile_ex_decile,3181,39.1072,-1.0829,0.0,-0.0807
# middle_two_quartiles,10611,39.77,-0.5505,-0.0,-0.0442
# top_quartile_ex_decile,3168,43.1503,-0.921,0.0,-0.0805
# top_decile,2120,47.6887,-0.4884,0.0,-0.0409

# %% [markdown]
# ## Figures

# %% [markdown]
# ![tfi_magnitude_daily_crypto_up_down_30s](figs/tfi_magnitude_daily_crypto_up_down_30s.png)

# %% [markdown]
# ![tfi_magnitude_daily_crypto_up_down_120s](figs/tfi_magnitude_daily_crypto_up_down_120s.png)

# %% [markdown]
# ![tfi_magnitude_daily_crypto_up_down_300s](figs/tfi_magnitude_daily_crypto_up_down_300s.png)

# %% [markdown]
# ![tfi_magnitude_daily_equity_index_30s](figs/tfi_magnitude_daily_equity_index_30s.png)

# %% [markdown]
# ![tfi_magnitude_daily_equity_index_120s](figs/tfi_magnitude_daily_equity_index_120s.png)

# %% [markdown]
# ![tfi_magnitude_daily_equity_index_300s](figs/tfi_magnitude_daily_equity_index_300s.png)

# %% [markdown]
# ![tfi_magnitude_ai_product_30s](figs/tfi_magnitude_ai_product_30s.png)

# %% [markdown]
# ![tfi_magnitude_ai_product_120s](figs/tfi_magnitude_ai_product_120s.png)

# %% [markdown]
# ![tfi_magnitude_ai_product_300s](figs/tfi_magnitude_ai_product_300s.png)

# %% [markdown]
# ![tfi_magnitude_sports_game_lines_30s](figs/tfi_magnitude_sports_game_lines_30s.png)

# %% [markdown]
# ![tfi_magnitude_sports_game_lines_120s](figs/tfi_magnitude_sports_game_lines_120s.png)

# %% [markdown]
# ![tfi_magnitude_sports_game_lines_300s](figs/tfi_magnitude_sports_game_lines_300s.png)
