# %% [markdown]
# # Block B Per-Market Heterogeneity
#
# Generated by `scripts/dali_tfi_deep_dive.py`.

# %% [markdown]
# ## Family Distribution Summary
#
# ```csv
# family_label,horizon_seconds,sign_convention,n_markets,frac_markets_hit_gt_55,frac_markets_positive_ev,median_market_hit_rate_pct,top_market_hit_rate_pct
# ai_product,30,inverse_maker_side,4,0.5,0.75,53.8816,56.0345
# ai_product,30,maker_side,4,0.25,0.25,43.4653,59.0361
# ai_product,120,inverse_maker_side,4,0.5,1.0,53.7559,55.7692
# ai_product,120,maker_side,4,0.25,0.0,45.531,57.5
# ai_product,300,inverse_maker_side,3,0.3333,1.0,48.2993,60.9272
# ai_product,300,maker_side,3,0.3333,0.0,51.7007,56.8376
# sports,30,inverse_maker_side,4,0.25,0.75,46.3676,58.4416
# sports,30,maker_side,4,0.0,0.25,41.7282,43.4109
# sports,120,inverse_maker_side,4,0.25,0.75,42.5605,59.0909
# sports,120,maker_side,4,0.0,0.25,42.958,52.2124
# sports,300,inverse_maker_side,4,0.25,0.75,47.0642,60.8621
# sports,300,maker_side,4,0.0,0.25,42.4661,47.619
# ```

# %% [markdown]
# ## Markets With Top-Decile Hit Rate Above 55%
#
# ```csv
# family_label,market_id,horizon_seconds,sign_convention,n_obs,hit_rate_pct,hit_rate_ci_low_pct,mean_return_cents,question
# ai_product,1664037,300,inverse_maker_side,151,60.9272,52.9801,8.0035,Will Anthropic have the best AI model at the end of April 2026?
# sports,564212,300,inverse_maker_side,580,60.8621,56.806,2.2596,Will the Houston Rockets win the NBA Western Conference Finals?
# sports,564212,120,inverse_maker_side,594,59.0909,55.0421,2.2801,Will the Houston Rockets win the NBA Western Conference Finals?
# ai_product,1664039,30,maker_side,249,59.0361,52.992,1.0451,Will OpenAI have the best AI model at the end of April 2026?
# sports,564212,30,inverse_maker_side,616,58.4416,54.7078,3.5435,Will the Houston Rockets win the NBA Western Conference Finals?
# ai_product,1664039,120,maker_side,240,57.5,51.0312,-0.3664,Will OpenAI have the best AI model at the end of April 2026?
# ai_product,1664039,300,maker_side,234,56.8376,50.0,-1.7789,Will OpenAI have the best AI model at the end of April 2026?
# ai_product,801450,30,inverse_maker_side,116,56.0345,46.5517,13.2884,Will OpenAI have the best AI model at the end of March 2026?
# ai_product,1664037,120,inverse_maker_side,156,55.7692,47.4359,7.3957,Will Anthropic have the best AI model at the end of April 2026?
# ai_product,801449,120,inverse_maker_side,160,55.625,47.7969,7.1253,Will Anthropic have the best AI model at the end of March 2026?
# ai_product,801449,30,inverse_maker_side,170,55.2941,48.8235,5.6033,Will Anthropic have the best AI model at the end of March 2026?
# ```

# %% [markdown]
# ## Figures
#
# ![block_b_per_market_top_decile_hit_distribution_300s](figs/block_b_per_market_top_decile_hit_distribution_300s.png)
